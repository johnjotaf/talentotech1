# %%
#from _typeshed import ProfileFunction
# mi calculadora
x=5
y=6
z=x+y
print(z)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-21ce88227aec> in <cell line: 0>()
#       4 y=6
#       5 z=x+y
# ----> 6 print(z)
#
# TypeError: 'str' object is not callable

# %% [markdown]
# # calculadora mas completa
